# %%
print("helloo world")
# Out:
# helloo world

# %%
import pandas as pd
import re

efe=pd.read_csv('Best Movie by Year Netflix.csv')

efe
# Out:
#     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
import pandas as pd
import re

efe=pd.read_csv('Best Movie by Year Netflix.csv')

efe.shape
# Out:
# (49, 6)

# %%
efe.describe
# Out:
# <bound method NDFrame.describe of     index                                           TITLE  RELEASE_YEAR  \
# 0       0                                 White Christmas          1954
# 1       1                            The Guns of Navarone          1961
# 2       2                                    My Fair Lady          1964
# 3       3                                Bonnie and Clyde          1967
# 4       4                                     Dirty Harry          1971
# 5       5                                    The Exorcist          1973
# 6       6                 Monty Python and the Holy Grail          1975
# 7       7                                     Taxi Driver          1976
# 8       8                                   Life of Brian          1979
# 9       9                                 The Blue Lagoon          1980
# 10     10                                           Annie          1982
# 11     11                                       Christine          1983
# ...

# %%
efe.values
# Out:
# array([[0, 'White Christmas', 1954, 7.5, 'romance', 'US'],
#        [1, 'The Guns of Navarone', 1961, 7.5, 'war', 'US'],
#        [2, 'My Fair Lady', 1964, 7.8, 'drama', 'US'],
#        [3, 'Bonnie and Clyde', 1967, 7.7, 'drama', 'US'],
#        [4, 'Dirty Harry', 1971, 7.7, 'thriller', 'US'],
#        [5, 'The Exorcist', 1973, 8.1, 'horror', 'US'],
#        [6, 'Monty Python and the Holy Grail', 1975, 8.2, 'comedy', 'GB'],
#        [7, 'Taxi Driver', 1976, 8.3, 'crime', 'US'],
#        [8, 'Life of Brian', 1979, 8.0, 'comedy', 'GB'],
#        [9, 'The Blue Lagoon', 1980, 5.8, 'romance', 'US'],
#        [10, 'Annie', 1982, 6.6, 'drama', 'US'],
#        [11, 'Christine', 1983, 6.7, 'horror', 'US'],
#        [12, 'Once Upon a Time in America', 1984, 8.3, 'drama', 'US'],
#        [13, 'Stand by Me', 1986, 8.1, 'drama', 'US'],
#        [14, 'Full Metal Jacket', 1987, 8.3, 'drama', 'GB'],
#        [15, 'When Harry Met Sally...', 1989, 7.7, 'romance', 'US'],
# ...
